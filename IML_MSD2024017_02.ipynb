# %% [markdown]
# **Linear Regression from Scratch**

# %% [markdown]
# Importing Python Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **Generate random points**

# %%
import numpy as np


x = np.random.randint(10, 50, 20)
y = np.random.randint(100, 1000, 20)

print("Generated x:", x)
print("Generated y:", y)
# Out:
# Generated x: [23 19 42 24 32 20 23 40 30 34 10 23 11 18 15 44 20 17 17 27]
# Generated y: [877 324 156 289 194 402 468 585 804 376 116 335 384 632 390 742 318 515
#  186 476]

# %% [markdown]
# Fit a Linear Regression Model

# %%
x_mean = np.mean(x)
y_mean = np.mean(y)

numerator = np.sum((x - x_mean) * (y - y_mean))
denominator = np.sum((x - x_mean) ** 2)
slope = numerator / denominator

b = y_mean - (slope * x_mean)

print("Slope (w):", slope)
print("Intercept (b):", b)

y_pred = slope * x + b
plt.scatter(x,y)
plt.plot(x, y_pred, color='red')
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Linear Regression")
plt.show()
# Out:
# Slope (w): 5.321214279843282
# Intercept (b): 298.3463108578318

# %% [markdown]
# Implement the Cost Function

# %%
def compute_cost(x, y, w, b):

    m = len(y)
    total = 0
    for i in range(m):
      y_pred = w * x[i] + b
      total += (y_pred - y[i]) ** 2
    return total / m


values = np.arange(100, 1001)
costs = []
for w in values:
  cost = compute_cost(x, y, w, b)
  costs.append(cost)


plt.plot(values, costs)
plt.xlabel("Weight (w)")
plt.ylabel("Cost")
plt.title("Cost Function")
plt.show()

# %% [markdown]
# **Visualize the original random data points as a scatter plot.**

# %%
import matplotlib.pyplot as plt
plt.scatter(x, y)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Scatter Plot of Data Points")
plt.show()

# %% [markdown]
# **The best-fit line obtained using your Linear Regression model**

# %%
learning_rate = 0.0001
num_iterations = 100

w = 0
b = 0
for i in range(num_iterations):
    y_pred = w * x + b

    dw = -(2 / len(x)) * np.sum(x * (y - y_pred))
    db = -(2 / len(x)) * np.sum(y - y_pred)

    w = w - learning_rate * dw
    b = b - learning_rate * db

    plt.scatter(x, y)
    plt.plot(x, y_pred, color='red')
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.title(f"Linear Regression - Iteration {i+1}")
    plt.show()
    plt.pause(0.1)
    plt.clf()

print(f"Final weight (w): {w}")
print(f"Final bias (b): {b}")
# Out:
# Final weight (w): 15.86172028634948
# Final bias (b): 1.3505850943966482

# %% [markdown]
# **cost function J(w) for different values of w.**

# %%
w_values = np.linspace(-10, 10, 100)

costs = [compute_cost(x, y, w, b) for w in w_values]

# Plot the cost function
plt.plot(w_values, costs)
plt.xlabel("Weight (w)")
plt.ylabel("Cost (J(w))")
plt.title("Cost Function J(w)")
plt.show()
